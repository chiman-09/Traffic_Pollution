# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import re

# %%
df = pd.read_csv('city_day.csv')
station_hr = pd.read_csv('station_hour.csv')
stations = pd.read_csv('stations.csv')
blore_index = df[df['City'] != 'Bengaluru'].index # index values that are not City Bengaluru
blore_df = df.drop(blore_index) # New Data frame blore_df formed by dropping index values obtained from above

blore_df=blore_df.dropna(subset=['AQI'])




station_hr_blr = station_hr[station_hr['StationId'].str.contains('KA')]  
station_name = stations[stations['City'] == 'Bengaluru']
id_to_name = {
     station_name._get_value(92,'StationName'):'KA002',
     station_name._get_value(93,'StationName'):'KA003',
     station_name._get_value(94,'StationName'):'KA004',
     station_name._get_value(95,'StationName'):'KA005',
     station_name._get_value(96,'StationName'):'KA006',
     station_name._get_value(97,'StationName'):'KA007',
     station_name._get_value(98,'StationName'):'KA008',
     station_name._get_value(99,'StationName'):'KA009',
     station_name._get_value(100,'StationName'):'KA010',
     station_name._get_value(101,'StationName'):'KA011',
}

station_hr_blr['StationName'] = id_to_name
station_hr_blr







#station_hr_blr.to_csv('station_hour_blr.csv')
# Out:
# /var/folders/6g/njzs5j491417vv5bbm0_rj480000gn/T/ipykernel_98757/2717904281.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   station_hr = pd.read_csv('station_hour.csv')
#     StationId                              StationName       City      State  \
# 92      KA002             BTM Layout, Bengaluru - CPCB  Bengaluru  Karnataka
# 93      KA003  BWSSB Kadabesanahalli, Bengaluru - CPCB  Bengaluru  Karnataka
# 94      KA004          Bapuji Nagar, Bengaluru - KSPCB  Bengaluru  Karnataka
# 95      KA005  City Railway Station, Bengaluru - KSPCB  Bengaluru  Karnataka
# 96      KA006                Hebbal, Bengaluru - KSPCB  Bengaluru  Karnataka
# 97      KA007      Hombegowda Nagar, Bengaluru - KSPCB  Bengaluru  Karnataka
# 98      KA008   Jayanagar 5th Block, Bengaluru - KSPCB  Bengaluru  Karnataka
# 99      KA009                 Peenya, Bengaluru - CPCB  Bengaluru  Karnataka
# ...
